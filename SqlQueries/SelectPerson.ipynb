-- %% [markdown]
-- A bit context

-- %% [markdown]
-- ## **Before migration:**
--
-- ![before-migration.png](attachment:before-migration.png)
--
--
-- ## **After migration:**
--
-- ![after-migration.png](attachment:after-migration.png)

-- %% [markdown]
-- # Example 1 Load a Fat person on local and azure

-- %%
exec sp_executesql N'SELECT [t].[TenantId], [t].[Id], [t].[FirstName], [t].[LastName], [t].[Timestamp], [s].[PersonEntityTenantId], [s].[PersonEntityId], [s].[Id], [s].[AvailableQuantity], [s].[Type], [p0].[PersonEntityTenantId], [p0].[PersonEntityId], [p0].[AssignedTeamId], [p0].[Name], [t].[Contact_EmailAddress], [p1].[ContactPersonEntityTenantId], [p1].[ContactPersonEntityId], [p1].[Id], [p1].[CountryCode], [p1].[Number], [d].[PersonEntityTenantId], [d].[PersonEntityId], [d].[Id], [d].[TrackerType], [d].[MobileNumber], [e].[PersonEntityTenantId], [e].[PersonEntityId], [e].[Id], [e].[FirstName], [e].[LastName], [e].[PhoneNumber_CountryCode], [e].[PhoneNumber_Number], [p2].[PersonEntityTenantId], [p2].[PersonEntityId], [p2].[ManagedTeamId], [p2].[Name], [t].[MedicalDetails_ProgramingImpairment], [t].[MedicalDetails_ProgramingImpairmentLevel], [t].[MedicalDetails_BloodType_Id], [t].[MedicalDetails_BloodType_Name], [p3].[MedicalDetailsPersonEntityTenantId], [p3].[MedicalDetailsPersonEntityId], [p3].[Id], [p3].[Name], [t].[PersonalDetails_DateOfBirth], [t].[PersonalDetails_Gender_Id], [t].[PersonalDetails_Gender_Name], [t].[PersonalDetails_HomeAddress_AddressLine1], [t].[PersonalDetails_HomeAddress_AddressLine2], [t].[PersonalDetails_HomeAddress_City], [t].[PersonalDetails_HomeAddress_CountryId], [t].[PersonalDetails_HomeAddress_County], [t].[PersonalDetails_HomeAddress_PostCode], [t].[PersonalDetails_WorkAddress_AddressLine1], [t].[PersonalDetails_WorkAddress_AddressLine2], [t].[PersonalDetails_WorkAddress_City], [t].[PersonalDetails_WorkAddress_CountryId], [t].[PersonalDetails_WorkAddress_County], [t].[PersonalDetails_WorkAddress_PostCode], [t].[PhysicalDetails_Height], [t].[PhysicalDetails_Build_Id], [t].[PhysicalDetails_Build_Name], [d0].[PhysicalDetailsPersonEntityTenantId], [d0].[PhysicalDetailsPersonEntityId], [d0].[Id], [d0].[AdditionalInformation], [d0].[Type], [t].[PhysicalDetails_EyeColour_Id], [t].[PhysicalDetails_EyeColour_Name], [t].[PhysicalDetails_HairColour_Id], [t].[PhysicalDetails_HairColour_Name], [p4].[PersonEntityTenantId], [p4].[PersonEntityId], [p4].[Id], [p5].[PersonEntityTenantId], [p5].[PersonEntityId], [p5].[Id], [t0].[PersonEntityTenantId], [t0].[PersonEntityId], [t0].[Id], [t0].[Name], [v].[PersonEntityTenantId], [v].[PersonEntityId], [v].[Id], [v].[Model], [v].[VehicleOwnedOrUsed], [v].[VehicleRegistration]
FROM (
    SELECT TOP(1) [p].[TenantId], [p].[Id], [p].[FirstName], [p].[LastName], [p].[Timestamp], [p].[Contact_EmailAddress], [p].[MedicalDetails_ProgramingImpairment], [p].[MedicalDetails_ProgramingImpairmentLevel], [p].[MedicalDetails_BloodType_Id], [p].[MedicalDetails_BloodType_Name], [p].[PersonalDetails_DateOfBirth], [p].[PersonalDetails_Gender_Id], [p].[PersonalDetails_Gender_Name], [p].[PersonalDetails_HomeAddress_AddressLine1], [p].[PersonalDetails_HomeAddress_AddressLine2], [p].[PersonalDetails_HomeAddress_City], [p].[PersonalDetails_HomeAddress_CountryId], [p].[PersonalDetails_HomeAddress_County], [p].[PersonalDetails_HomeAddress_PostCode], [p].[PersonalDetails_WorkAddress_AddressLine1], [p].[PersonalDetails_WorkAddress_AddressLine2], [p].[PersonalDetails_WorkAddress_City], [p].[PersonalDetails_WorkAddress_CountryId], [p].[PersonalDetails_WorkAddress_County], [p].[PersonalDetails_WorkAddress_PostCode], [p].[PhysicalDetails_Height], [p].[PhysicalDetails_Build_Id], [p].[PhysicalDetails_Build_Name], [p].[PhysicalDetails_EyeColour_Id], [p].[PhysicalDetails_EyeColour_Name], [p].[PhysicalDetails_HairColour_Id], [p].[PhysicalDetails_HairColour_Name]
    FROM [EF6].[People] AS [p]
    WHERE ([p].[TenantId] = @__ef_filter__p_0) AND (([p].[TenantId] = @__get_Item_0) AND ([p].[Id] = @__get_Item_1))
) AS [t]
LEFT JOIN [EF6].[Subscription] AS [s] ON ([t].[TenantId] = [s].[PersonEntityTenantId]) AND ([t].[Id] = [s].[PersonEntityId])
LEFT JOIN [EF6].[People_Ancestors] AS [p0] ON ([t].[TenantId] = [p0].[PersonEntityTenantId]) AND ([t].[Id] = [p0].[PersonEntityId])
LEFT JOIN [EF6].[People_PhoneNumbers] AS [p1] ON ([t].[TenantId] = [p1].[ContactPersonEntityTenantId]) AND ([t].[Id] = [p1].[ContactPersonEntityId])
LEFT JOIN [EF6].[Tracker] AS [d] ON ([t].[TenantId] = [d].[PersonEntityTenantId]) AND ([t].[Id] = [d].[PersonEntityId])
LEFT JOIN [EF6].[EmergencyContact] AS [e] ON ([t].[TenantId] = [e].[PersonEntityTenantId]) AND ([t].[Id] = [e].[PersonEntityId])
LEFT JOIN [EF6].[People_Descendants] AS [p2] ON ([t].[TenantId] = [p2].[PersonEntityTenantId]) AND ([t].[Id] = [p2].[PersonEntityId])
LEFT JOIN [EF6].[People_MedicalConditions] AS [p3] ON ([t].[TenantId] = [p3].[MedicalDetailsPersonEntityTenantId]) AND ([t].[Id] = [p3].[MedicalDetailsPersonEntityId])
LEFT JOIN [EF6].[DistinguishingFeature] AS [d0] ON ([t].[TenantId] = [d0].[PhysicalDetailsPersonEntityTenantId]) AND ([t].[Id] = [d0].[PhysicalDetailsPersonEntityId])
LEFT JOIN [EF6].[People_RiskProfile] AS [p4] ON ([t].[TenantId] = [p4].[PersonEntityTenantId]) AND ([t].[Id] = [p4].[PersonEntityId])
LEFT JOIN [EF6].[People_Roles] AS [p5] ON ([t].[TenantId] = [p5].[PersonEntityTenantId]) AND ([t].[Id] = [p5].[PersonEntityId])
LEFT JOIN [EF6].[Tag] AS [t0] ON ([t].[TenantId] = [t0].[PersonEntityTenantId]) AND ([t].[Id] = [t0].[PersonEntityId])
LEFT JOIN [EF6].[VehicleDetails] AS [v] ON ([t].[TenantId] = [v].[PersonEntityTenantId]) AND ([t].[Id] = [v].[PersonEntityId])
ORDER BY [t].[TenantId], [t].[Id], [s].[PersonEntityTenantId], [s].[PersonEntityId], [s].[Id], [p0].[PersonEntityTenantId], [p0].[PersonEntityId], [p0].[AssignedTeamId], [p1].[ContactPersonEntityTenantId], [p1].[ContactPersonEntityId], [p1].[Id], [d].[PersonEntityTenantId], [d].[PersonEntityId], [d].[Id], [e].[PersonEntityTenantId], [e].[PersonEntityId], [e].[Id], [p2].[PersonEntityTenantId], [p2].[PersonEntityId], [p2].[ManagedTeamId], [p3].[MedicalDetailsPersonEntityTenantId], [p3].[MedicalDetailsPersonEntityId], [p3].[Id], [d0].[PhysicalDetailsPersonEntityTenantId], [d0].[PhysicalDetailsPersonEntityId], [d0].[Id], [p4].[PersonEntityTenantId], [p4].[PersonEntityId], [p4].[Id], [p5].[PersonEntityTenantId], [p5].[PersonEntityId], [p5].[Id], [t0].[PersonEntityTenantId], [t0].[PersonEntityId], [t0].[Id], [v].[PersonEntityTenantId], [v].[PersonEntityId]
',
N'@__ef_filter__p_0 uniqueidentifier,@__get_Item_0 uniqueidentifier,@__get_Item_1 uniqueidentifier',@__ef_filter__p_0='B950DE8C-9BA1-49A5-9D16-5F4B4C125214',@__get_Item_0='B950DE8C-9BA1-49A5-9D16-5F4B4C125214',@__get_Item_1='C349AC05-068A-40C4-B4E0-D98D00C1D1A0'

-- %%
SELECT count(1), Count(distinct [t].[Id])
FROM (
    SELECT Top 1 [p].[TenantId], [p].[Id], [p].[FirstName], [p].[LastName], [p].[Timestamp], [p].[Contact_EmailAddress], [p].[MedicalDetails_ProgramingImpairment], [p].[MedicalDetails_ProgramingImpairmentLevel], [p].[MedicalDetails_BloodType_Id], [p].[MedicalDetails_BloodType_Name], [p].[PersonalDetails_DateOfBirth], [p].[PersonalDetails_Gender_Id], [p].[PersonalDetails_Gender_Name], [p].[PersonalDetails_HomeAddress_AddressLine1], [p].[PersonalDetails_HomeAddress_AddressLine2], [p].[PersonalDetails_HomeAddress_City], [p].[PersonalDetails_HomeAddress_CountryId], [p].[PersonalDetails_HomeAddress_County], [p].[PersonalDetails_HomeAddress_PostCode], [p].[PersonalDetails_WorkAddress_AddressLine1], [p].[PersonalDetails_WorkAddress_AddressLine2], [p].[PersonalDetails_WorkAddress_City], [p].[PersonalDetails_WorkAddress_CountryId], [p].[PersonalDetails_WorkAddress_County], [p].[PersonalDetails_WorkAddress_PostCode], [p].[PhysicalDetails_Height], [p].[PhysicalDetails_Build_Id], [p].[PhysicalDetails_Build_Name], [p].[PhysicalDetails_EyeColour_Id], [p].[PhysicalDetails_EyeColour_Name], [p].[PhysicalDetails_HairColour_Id], [p].[PhysicalDetails_HairColour_Name]
    FROM [EF6].[People] AS [p]
    where FirstName = 'Fat'
) AS [t]
LEFT JOIN [EF6].[Subscription] AS [s] ON ([t].[TenantId] = [s].[PersonEntityTenantId]) AND ([t].[Id] = [s].[PersonEntityId])
LEFT JOIN [EF6].[People_Ancestors] AS [p0] ON ([t].[TenantId] = [p0].[PersonEntityTenantId]) AND ([t].[Id] = [p0].[PersonEntityId])
LEFT JOIN [EF6].[People_PhoneNumbers] AS [p1] ON ([t].[TenantId] = [p1].[ContactPersonEntityTenantId]) AND ([t].[Id] = [p1].[ContactPersonEntityId])
LEFT JOIN [EF6].[Tracker] AS [d] ON ([t].[TenantId] = [d].[PersonEntityTenantId]) AND ([t].[Id] = [d].[PersonEntityId])
LEFT JOIN [EF6].[EmergencyContact] AS [e] ON ([t].[TenantId] = [e].[PersonEntityTenantId]) AND ([t].[Id] = [e].[PersonEntityId])
LEFT JOIN [EF6].[People_Descendants] AS [p2] ON ([t].[TenantId] = [p2].[PersonEntityTenantId]) AND ([t].[Id] = [p2].[PersonEntityId])
LEFT JOIN [EF6].[People_MedicalConditions] AS [p3] ON ([t].[TenantId] = [p3].[MedicalDetailsPersonEntityTenantId]) AND ([t].[Id] = [p3].[MedicalDetailsPersonEntityId])
LEFT JOIN [EF6].[DistinguishingFeature] AS [d0] ON ([t].[TenantId] = [d0].[PhysicalDetailsPersonEntityTenantId]) AND ([t].[Id] = [d0].[PhysicalDetailsPersonEntityId])
LEFT JOIN [EF6].[People_RiskProfile] AS [p4] ON ([t].[TenantId] = [p4].[PersonEntityTenantId]) AND ([t].[Id] = [p4].[PersonEntityId])
LEFT JOIN [EF6].[People_Roles] AS [p5] ON ([t].[TenantId] = [p5].[PersonEntityTenantId]) AND ([t].[Id] = [p5].[PersonEntityId])
LEFT JOIN [EF6].[Tag] AS [t0] ON ([t].[TenantId] = [t0].[PersonEntityTenantId]) AND ([t].[Id] = [t0].[PersonEntityId])
LEFT JOIN [EF6].[VehicleDetails] AS [v] ON ([t].[TenantId] = [v].[PersonEntityTenantId]) AND ([t].[Id] = [v].[PersonEntityId])

-- %%
SELECT count(1), Count(distinct [t].[Id])
FROM (
    SELECT [p].[TenantId], [p].[Id], [p].[FirstName], [p].[LastName], [p].[Timestamp], [p].[Contact_EmailAddress], [p].[MedicalDetails_ProgramingImpairment], [p].[MedicalDetails_ProgramingImpairmentLevel], [p].[MedicalDetails_BloodType_Id], [p].[MedicalDetails_BloodType_Name], [p].[PersonalDetails_DateOfBirth], [p].[PersonalDetails_Gender_Id], [p].[PersonalDetails_Gender_Name], [p].[PersonalDetails_HomeAddress_AddressLine1], [p].[PersonalDetails_HomeAddress_AddressLine2], [p].[PersonalDetails_HomeAddress_City], [p].[PersonalDetails_HomeAddress_CountryId], [p].[PersonalDetails_HomeAddress_County], [p].[PersonalDetails_HomeAddress_PostCode], [p].[PersonalDetails_WorkAddress_AddressLine1], [p].[PersonalDetails_WorkAddress_AddressLine2], [p].[PersonalDetails_WorkAddress_City], [p].[PersonalDetails_WorkAddress_CountryId], [p].[PersonalDetails_WorkAddress_County], [p].[PersonalDetails_WorkAddress_PostCode], [p].[PhysicalDetails_Height], [p].[PhysicalDetails_Build_Id], [p].[PhysicalDetails_Build_Name], [p].[PhysicalDetails_EyeColour_Id], [p].[PhysicalDetails_EyeColour_Name], [p].[PhysicalDetails_HairColour_Id], [p].[PhysicalDetails_HairColour_Name]
    FROM [EF6].[People] AS [p]
) AS [t]
LEFT JOIN [EF6].[Subscription] AS [s] ON ([t].[TenantId] = [s].[PersonEntityTenantId]) AND ([t].[Id] = [s].[PersonEntityId])
LEFT JOIN [EF6].[People_Ancestors] AS [p0] ON ([t].[TenantId] = [p0].[PersonEntityTenantId]) AND ([t].[Id] = [p0].[PersonEntityId])
LEFT JOIN [EF6].[People_PhoneNumbers] AS [p1] ON ([t].[TenantId] = [p1].[ContactPersonEntityTenantId]) AND ([t].[Id] = [p1].[ContactPersonEntityId])
LEFT JOIN [EF6].[Tracker] AS [d] ON ([t].[TenantId] = [d].[PersonEntityTenantId]) AND ([t].[Id] = [d].[PersonEntityId])
LEFT JOIN [EF6].[EmergencyContact] AS [e] ON ([t].[TenantId] = [e].[PersonEntityTenantId]) AND ([t].[Id] = [e].[PersonEntityId])
LEFT JOIN [EF6].[People_Descendants] AS [p2] ON ([t].[TenantId] = [p2].[PersonEntityTenantId]) AND ([t].[Id] = [p2].[PersonEntityId])
LEFT JOIN [EF6].[People_MedicalConditions] AS [p3] ON ([t].[TenantId] = [p3].[MedicalDetailsPersonEntityTenantId]) AND ([t].[Id] = [p3].[MedicalDetailsPersonEntityId])
LEFT JOIN [EF6].[DistinguishingFeature] AS [d0] ON ([t].[TenantId] = [d0].[PhysicalDetailsPersonEntityTenantId]) AND ([t].[Id] = [d0].[PhysicalDetailsPersonEntityId])
LEFT JOIN [EF6].[People_RiskProfile] AS [p4] ON ([t].[TenantId] = [p4].[PersonEntityTenantId]) AND ([t].[Id] = [p4].[PersonEntityId])
LEFT JOIN [EF6].[People_Roles] AS [p5] ON ([t].[TenantId] = [p5].[PersonEntityTenantId]) AND ([t].[Id] = [p5].[PersonEntityId])
LEFT JOIN [EF6].[Tag] AS [t0] ON ([t].[TenantId] = [t0].[PersonEntityTenantId]) AND ([t].[Id] = [t0].[PersonEntityId])
LEFT JOIN [EF6].[VehicleDetails] AS [v] ON ([t].[TenantId] = [v].[PersonEntityTenantId]) AND ([t].[Id] = [v].[PersonEntityId])

-- %% [markdown]
-- # Example 2 Auto Id

-- %%
SELECT * FROM [EFExample].[EF6].[Tag] order by Id

-- %% [markdown]
-- # Example 3

-- %%
begin tran
exec sp_executesql N'SET NOCOUNT ON;
UPDATE [EF6].[People] SET [MedicalDetails_ProgramingImpairmentLevel] = @p0, [MedicalDetails_BloodType_Id] = @p1, [MedicalDetails_BloodType_Name] = @p2
WHERE [Id] = @p3 AND [TenantId] = @p4 AND [Timestamp] = @p5;
SELECT [Timestamp]
FROM [EF6].[People]
WHERE @@ROWCOUNT = 1 AND [Id] = @p3 AND [TenantId] = @p4;

DELETE FROM [EF6].[People_MedicalConditions]
WHERE [Id] = @p6 AND [MedicalDetailsPersonEntityId] = @p7 AND [MedicalDetailsPersonEntityTenantId] = @p8;
SELECT @@ROWCOUNT;

UPDATE [EF6].[People_MedicalConditions] SET [Name] = @p9
WHERE [Id] = @p10 AND [MedicalDetailsPersonEntityId] = @p11 AND [MedicalDetailsPersonEntityTenantId] = @p12;
SELECT @@ROWCOUNT;

UPDATE [EF6].[People_MedicalConditions] SET [Name] = @p13
WHERE [Id] = @p14 AND [MedicalDetailsPersonEntityId] = @p15 AND [MedicalDetailsPersonEntityTenantId] = @p16;
SELECT @@ROWCOUNT;

UPDATE [EF6].[People_MedicalConditions] SET [Name] = @p17
WHERE [Id] = @p18 AND [MedicalDetailsPersonEntityId] = @p19 AND [MedicalDetailsPersonEntityTenantId] = @p20;
SELECT @@ROWCOUNT;

',N'@p3 uniqueidentifier
,@p4 uniqueidentifier
,@p5 varbinary(8)
,@p0 nvarchar(max) 
,@p1 uniqueidentifier
,@p2 nvarchar(100)
,@p6 uniqueidentifier
,@p7 uniqueidentifier
,@p8 uniqueidentifier
,@p10 uniqueidentifier
,@p11 uniqueidentifier
,@p12 uniqueidentifier
,@p9 nvarchar(100)
,@p14 uniqueidentifier
,@p15 uniqueidentifier
,@p16 uniqueidentifier
,@p13 nvarchar(100)
,@p18 uniqueidentifier
,@p19 uniqueidentifier
,@p20 uniqueidentifier
,@p17 nvarchar(100)'
,@p3='C542DCB3-6610-4444-B623-BC7B14AE4768'
,@p4='D52D18AA-E0C0-4395-9496-BB36323476FD'
,@p5=0x0000000000000812
,@p0=N'Sed ut perspiciatis, unde omnis iste natus error sit voluptatem accusantium doloremque laudantium, totam rem aperiam eaque ipsa, quae ab illo inventore veritatis et quasi architecto beatae vitae dicta sunt, explicabo. Nemo enim ipsam voluptatem, quia voluptas sit, aspernatur aut odit aut fugit, sed quia consequuntur magni dolores eos, qui ratione voluptatem sequi nesciunt, neque porro quisquam est, qui dolorem ipsum, quia dolor sit, amet, consectetur, adipisci velit, sed quia non numquam eius modi tempora incidunt, ut labore et dolore magnam aliquam quaerat voluptatem. Ut enim ad minima veniam, quis nostrum exercitationem ullam corporis suscipit laboriosam, nisi ut aliquid ex ea commodi consequatur? Quis autem vel eum iure reprehenderit, qui in ea voluptate velit esse, quam nihil molestiae consequatur, vel illum, qui dolorem eum fugiat, quo voluptas nulla pariatur?
[33] At vero eos et accusamus et iusto odio dignissimos ducimus, qui blanditiis praesentium voluptatum deleniti atque corrupti, quos dolores et quas molestias excepturi sint, obcaecati cupiditate non provident, similique sunt in culpa, qui officia deserunt mollitia animi, id est laborum et dolorum fuga. Et harum quidem rerum facilis est et expedita distinctio. Nam libero tempore, cum soluta nobis est eligendi optio, cumque nihil impedit, quo minus id, quod maxime placeat, facere possimus, omnis voluptas assumenda est, omnis dolor repellendus. Temporibus autem quibusdam et aut officiis debitis aut rerum necessitatibus saepe eveniet, ut et voluptates repudiandae sint et molestiae non recusandae. Itaque earum rerum hic tenetur a sapiente delectus, ut aut reiciendis voluptatibus maiores alias consequatur aut perferendis doloribus asperiores repellat.Sed ut perspiciatis, unde omnis iste natus error sit voluptatem accusantium doloremque laudantium, totam rem aperiam eaque ipsa, quae ab illo inventore veritatis et quasi architecto beatae vitae dicta sunt, explicabo. Nemo enim ipsam voluptatem, quia voluptas sit, aspernatur aut odit aut fugit, sed quia consequuntur magni dolores eos, qui ratione voluptatem sequi nesciunt, neque porro quisquam est, qui dolorem ipsum, quia dolor sit, amet, consectetur, adipisci velit, sed quia non numquam eius modi tempora incidunt, ut labore et dolore magnam aliquam quaerat voluptatem. Ut enim ad minima veniam, quis nostrum exercitationem ullam corporis suscipit laboriosam, nisi ut aliquid ex ea commodi consequatur? Quis autem vel eum iure reprehenderit, qui in ea voluptate velit esse, quam nihil molestiae consequatur, vel illum, qui dolorem eum fugiat, quo voluptas nulla pariatur?
[33] At vero eos et accusamus et iusto odio dignissimos ducimus, qui blanditiis praesentium voluptatum deleniti atque corrupti, quos dolores et quas molestias excepturi sint, obcaecati cupiditate non provident, similique sunt in culpa, qui officia deserunt mollitia animi, id est laborum et dolorum fuga. Et harum quidem rerum facilis est et expedita distinctio. Nam libero tempore, cum soluta nobis est eligendi optio, cumque nihil impedit, quo minus id, quod maxime placeat, facere possimus, omnis voluptas assumenda est, omnis dolor repellendus. Temporibus autem quibusdam et aut officiis debitis aut rerum necessitatibus saepe eveniet, ut et voluptates repudiandae sint et molestiae non recusandae. Itaque earum rerum hic tenetur a sapiente delectus, ut aut reiciendis voluptatibus maiores alias consequatur aut perferendis doloribus asperiores repellat.Sed ut perspiciatis, unde omnis iste natus error sit voluptatem accusantium doloremque laudantium, totam rem aperiam eaque ipsa, quae ab illo inventore veritatis et quasi architecto beatae vitae dicta sunt, explicabo. Nemo enim ipsam voluptatem, quia voluptas sit, aspernatur aut odit aut fugit, sed quia consequuntur magni dolores eos, qui ratione voluptatem sequi nesciunt, neque porro quisquam est, qui dolorem ipsum, quia dolor sit, amet, consectetur, adipisci velit, sed quia non numquam eius modi tempora incidunt, ut labore et dolore magnam aliquam quaerat voluptatem. Ut enim ad minima veniam, quis nostrum exercitationem ullam corporis suscipit laboriosam, nisi ut aliquid ex ea commodi consequatur? Quis autem vel eum iure reprehenderit, qui in ea voluptate velit esse, quam nihil molestiae consequatur, vel illum, qui dolorem eum fugiat, quo voluptas nulla pariatur?
[33] At vero eos et accusamus et iusto odio dignissimos ducimus, qui blanditiis praesentium voluptatum deleniti atque corrupti, quos dolores et quas molestias excepturi sint, obcaecati cupiditate non provident, similique sunt in culpa, qui officia deserunt mollitia animi, id est laborum et dolorum fuga. Et harum quidem rerum facilis est et expedita distinctio. Nam libero tempore, cum soluta nobis est eligendi optio, cumque nihil impedit, quo minus id, quod maxime placeat, facere possimus, omnis voluptas assumenda est, omnis dolor repellendus. Temporibus autem quibusdam et aut officiis debitis aut rerum necessitatibus saepe eveniet, ut et voluptates repudiandae sint et molestiae non recusandae. Itaque earum rerum hic tenetur a sapiente delectus, ut aut reiciendis voluptatibus maiores alias consequatur aut perferendis doloribus asperiores repellat.Sed ut perspiciatis, unde omnis iste natus error sit voluptatem accusantium doloremque laudantium, totam rem aperiam eaque ipsa, quae ab illo inventore veritatis et quasi architecto beatae vitae dicta sunt, explicabo. Nemo enim ipsam voluptatem, quia voluptas sit, aspernatur aut odit aut fugit, sed quia consequuntur magni dolores eos, qui ratione voluptatem sequi nesciunt, neque porro quisquam est, qui dolorem ipsum, quia dolor sit, amet, consectetur, adipisci velit, sed quia non numquam eius modi tempora incidunt, ut labore et dolore magnam aliquam quaerat voluptatem. Ut enim ad minima veniam, quis nostrum exercitationem ullam corporis suscipit laboriosam, nisi ut aliquid ex ea commodi consequatur? Quis autem vel eum iure reprehenderit, qui in ea voluptate velit esse, quam nihil molestiae consequatur, vel illum, qui dolorem eum fugiat, quo voluptas nulla pariatur?
[33] At vero eos et accusamus et iusto odio dignissimos ducimus, qui blanditiis praesentium voluptatum deleniti atque corrupti, quos dolores et quas molestias excepturi sint, obcaecati cupiditate non provident, similique sunt in culpa, qui officia deserunt mollitia animi, id est laborum et dolorum fuga. Et harum quidem rerum facilis est et expedita distinctio. Nam libero tempore, cum soluta nobis est eligendi optio, cumque nihil impedit, quo minus id, quod maxime placeat, facere possimus, omnis voluptas assumenda est, omnis dolor repellendus. Temporibus autem quibusdam et aut officiis debitis aut rerum necessitatibus saepe eveniet, ut et voluptates repudiandae sint et molestiae non recusandae. Itaque earum rerum hic tenetur a sapiente delectus, ut aut reiciendis voluptatibus maiores alias consequatur aut perferendis doloribus asperiores repellat.'
,@p1='A07D2136-C330-44FF-948C-28F65B7F3CD7'
,@p2=N'NamedProperty b8330500-831d-428c-a5b1-9c0c1d439109'

,@p6='78FFA0E3-F63F-42F0-AD45-373240CB68F3'

,@p7='C542DCB3-6610-4444-B623-BC7B14AE4768'

,@p8='D52D18AA-E0C0-4395-9496-BB36323476FD'
,@p10='4C54537E-65BE-4607-B63F-82272FC3F462'
,@p11='C542DCB3-6610-4444-B623-BC7B14AE4768'
,@p12='D52D18AA-E0C0-4395-9496-BB36323476FD'
,@p9=N'NamedProperty 309f6e2c-4263-40cf-8664-7a0ecad2ca02'
,@p14='767FAEDB-83EA-4690-A46A-CF5F21EAC5C0'
,@p15='C542DCB3-6610-4444-B623-BC7B14AE4768'
,@p16='D52D18AA-E0C0-4395-9496-BB36323476FD'
,@p13=N'NamedProperty 2da5f925-d1cc-438c-b951-d96a91345cb7'
,@p18='7CC8EBBC-50B4-4E0D-9394-521FC2385A78'
,@p19='C542DCB3-6610-4444-B623-BC7B14AE4768'
,@p20='D52D18AA-E0C0-4395-9496-BB36323476FD'
,@p17=N'NamedProperty 028a2cab-4ddf-4e1a-ab66-30be29cf56d5'
rollback  tran
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.010
-- <table><tr><th>Timestamp</th></tr><tr><td>0x0000000000000815</td></tr></table>
-- <table><tr><th>(No column name)</th></tr><tr><td>1</td></tr></table>
-- <table><tr><th>(No column name)</th></tr><tr><td>0</td></tr></table>
-- <table><tr><th>(No column name)</th></tr><tr><td>0</td></tr></table>
-- <table><tr><th>(No column name)</th></tr><tr><td>0</td></tr></table>

-- %% [markdown]
-- [c# - EF Core doesn't detect changes when adding new entry on a relation for saved entities - Stack Overflow](https:\stackoverflow.com\questions\73297693\ef-core-doesnt-detect-changes-when-adding-new-entry-on-a-relation-for-saved-ent)
--
-- [Generated Values - EF Core | Microsoft Learn](https://learn.microsoft.com/en-us/ef/core/modeling/generated-properties?tabs=fluent-api#overriding-value-generation)

-- %% [markdown]
-- # Example 4 What if we have only a ID

-- %% [markdown]
-- # Example 5 try to add a index for email adress

-- %% [markdown]
-- # EF 8 ! :D  ComplexType

-- %% [markdown]
-- [EF Core 8 RC1: Complex types as value objects - .NET Blog (microsoft.com)](https://devblogs.microsoft.com/dotnet/announcing-ef8-rc1/)
--
--
--
-- 1\. Collection is not supported [Complex type collection support · Issue #31237 · dotnet/efcore · GitHub](https://github.com/dotnet/efcore/issues/31237) - and it will be by serialize to json <span style="color: var(--vscode-foreground);">probably</span>
--
-- 2\. Can't use ComplexType on nullable property
--
--
--
--
--
-- [SensitiveDataLogging with ComplexProperty: Unable to cast RuntimeComplexType to type IEntityType · Issue #32198 · dotnet/efcore · GitHub](https://github.com/dotnet/efcore/issues/32198)
